# %%
import pandas as pd
df = pd.read_csv('C:/Users/Luyao Chen/OneDrive/Big Data Programming/Final/environment.csv')
df.head(5)
# Out:
# F:\Development\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10,11,14,15,20,22,23,25,39,40,44,45,59,63,64,67,68,69,84,85,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       STATION                STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  WBAN:94728  NY CITY CENTRAL PARK NY US       39.6   40.7889   -73.9669
# 1  WBAN:94728  NY CITY CENTRAL PARK NY US       39.6   40.7889   -73.9669
# 2  WBAN:94728  NY CITY CENTRAL PARK NY US       39.6   40.7889   -73.9669
# 3  WBAN:94728  NY CITY CENTRAL PARK NY US       39.6   40.7889   -73.9669
# 4  WBAN:94728  NY CITY CENTRAL PARK NY US       39.6   40.7889   -73.9669
#
#                DATE REPORTTPYE HOURLYSKYCONDITIONS HOURLYVISIBILITY  \
# 0  2009-01-01 00:51      FM-15           FEW:02 44            10.00
# 1  2009-01-01 01:51      FM-15                 NaN            10.00
# ...

# %%
df.dtypes
# Out:
# STATION                               object
# STATION_NAME                          object
# ELEVATION                            float64
# LATITUDE                             float64
# LONGITUDE                            float64
# DATE                                  object
# REPORTTPYE                            object
# HOURLYSKYCONDITIONS                   object
# HOURLYVISIBILITY                      object
# HOURLYPRSENTWEATHERTYPE               object
# HOURLYDRYBULBTEMPF                    object
# HOURLYDRYBULBTEMPC                    object
# HOURLYWETBULBTEMPF                   float64
# HOURLYWETBULBTEMPC                   float64
# HOURLYDewPointTempF                   object
# HOURLYDewPointTempC                   object
# HOURLYRelativeHumidity               float64
# HOURLYWindSpeed                      float64
# HOURLYWindDirection                   object
# HOURLYWindGustSpeed                  float64
# HOURLYStationPressure                 object
# ...

# %%
def WeatherTypeParser(code):
    code = str(code)
    if code == 'nan':
        w = 'normal'
    elif 'RA'in code or 'DZ'in code or 'UP' in code :
        w = 'rain'
    elif 'SN'in code or 'SG'in code or 'IC'in code or 'PL' in code or 'GR' in code or 'GS' in code:
        w = 'snow'
    elif 'BR'in code or 'FG'in code or 'FU'in code or 'SA' in code :
        w = 'fog'
    else:
        w = 'normal'
    return w

df1 = df.loc[:,['DATE','HOURLYPRSENTWEATHERTYPE','HOURLYDRYBULBTEMPC','HOURLYWindSpeed']]
df1['HOURLYPRSENTWEATHERTYPE']= df1['HOURLYPRSENTWEATHERTYPE'].map(lambda x:WeatherTypeParser(x))

df2 = df1.rename(columns={"HOURLYPRSENTWEATHERTYPE": "WEATHER", "HOURLYDRYBULBTEMPC": "TEMPC","HOURLYWindSpeed":"WIND"})
df2.head(5)
# Out:
#                DATE WEATHER TEMPC  WIND
# 0  2009-01-01 00:51  normal  -7.8  18.0
# 1  2009-01-01 01:51  normal  -7.8  18.0
# 2  2009-01-01 02:51  normal  -7.8  18.0
# 3  2009-01-01 03:51  normal  -8.3   8.0
# 4  2009-01-01 04:51  normal  -8.3  11.0

# %%
df2.head(5)
def WeatherDateParser(date):
     return date[0:-3]

df2['DATE']=df2['DATE'].map(lambda x:WeatherDateParser(x))
df2.head(5)
# Out:
#             DATE WEATHER TEMPC  WIND
# 0  2009-01-01 00  normal  -7.8  18.0
# 1  2009-01-01 01  normal  -7.8  18.0
# 2  2009-01-01 02  normal  -7.8  18.0
# 3  2009-01-01 03  normal  -8.3   8.0
# 4  2009-01-01 04  normal  -8.3  11.0

# %%
df2.shape
df2.head(5)
# Out:
#             DATE WEATHER TEMPC  WIND
# 0  2009-01-01 00  normal  -7.8  18.0
# 1  2009-01-01 01  normal  -7.8  18.0
# 2  2009-01-01 02  normal  -7.8  18.0
# 3  2009-01-01 03  normal  -8.3   8.0
# 4  2009-01-01 04  normal  -8.3  11.0

# %%
repeat = []
for i in range(0,df2.shape[0]-1):
    if df2.loc[i]['DATE'] == df2.loc[i+1]['DATE']:
        repeat.append(i)

# %%
df2.drop(df.index[repeat], inplace=True)
df2.shape
# Out:
# (72462, 4)

# %%
df2.to_csv('C:/Users/Luyao Chen/OneDrive/Big Data Programming/Final/env.csv')
