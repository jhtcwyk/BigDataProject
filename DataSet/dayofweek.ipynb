# %%
import pandas as pd
df = pd.read_csv('D:/Study/graduate 17 spring/programming for big data/project/BigDataProject/DataSet/env.csv')
df['DATE'] = df['DATE'].astype('datetime64[ns]')
df.dtypes
# Out:
# Unnamed: 0             int64
# DATE          datetime64[ns]
# WEATHER               object
# TEMPC                 object
# WIND                 float64
# dtype: object

# %%
df['dayofweek']=df['DATE'].dt.dayofweek

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# DATE          datetime64[ns]
# WEATHER               object
# TEMPC                 object
# WIND                 float64
# dayofweek              int64
# dtype: object

# %%
df.head(50)
# Out:
#     Unnamed: 0                DATE WEATHER TEMPC  WIND  dayofweek
# 0            0 2009-01-01 00:00:00  normal  -7.8  18.0          3
# 1            1 2009-01-01 01:00:00  normal  -7.8  18.0          3
# 2            2 2009-01-01 02:00:00  normal  -7.8  18.0          3
# 3            3 2009-01-01 03:00:00  normal  -8.3   8.0          3
# 4            4 2009-01-01 04:00:00  normal  -8.3  11.0          3
# 5            5 2009-01-01 05:00:00  normal  -8.9  18.0          3
# 6            6 2009-01-01 06:00:00  normal  -9.4  14.0          3
# 7            7 2009-01-01 07:00:00  normal  -9.4   8.0          3
# 8            8 2009-01-01 08:00:00  normal  -9.4  15.0          3
# 9            9 2009-01-01 09:00:00  normal  -8.3   8.0          3
# 10          10 2009-01-01 10:00:00  normal  -7.2  14.0          3
# 11          11 2009-01-01 11:00:00  normal  -6.1  14.0          3
# 12          12 2009-01-01 12:00:00  normal  -5.0  11.0          3
# ...

# %%
df.to_csv('D:/Study/graduate 17 spring/programming for big data/project/BigDataProject/DataSet/env2.csv')
